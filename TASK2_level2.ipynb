# %% [markdown]
# <a href="https://colab.research.google.com/github/RashmiThakre/Cognifyz-Tasks/blob/main/TASK2_level2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from itertools import combinations
from collections import Counter
from collections import defaultdict

# %%
df= pd.read_csv('/Dataset .csv')

# %%
print(df.columns)
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df['Cuisines'] = df['Cuisines'].astype(str).apply(lambda x: x.split(',') if x != 'nan' else [])

# %%
all_combinations = df['Cuisines'].apply(lambda x: list(combinations(x, 2)))

# %%
all_combinations_flat = [item for sublist in all_combinations for item in sublist]
combination_counts = Counter(all_combinations_flat)

# %%
most_common_combinations = combination_counts.most_common()

# %%
print("Most common cuisine combinations:")
for combo, count in most_common_combinations:
    print(f"{combo}: {count} times")
# Out:
# Most common cuisine combinations:
# ('North Indian', ' Chinese'): 1314 times
# ('North Indian', ' Mughlai'): 689 times
# ('North Indian', ' Fast Food'): 296 times
# ('North Indian', ' South Indian'): 258 times
# ('Bakery', ' Desserts'): 254 times
# ('North Indian', ' Continental'): 249 times
# (' Mughlai', ' Chinese'): 230 times
# (' North Indian', ' Chinese'): 202 times
# ('Chinese', ' North Indian'): 202 times
# ('Bakery', ' Fast Food'): 196 times
# (' Chinese', ' Fast Food'): 173 times
# ('Chinese', ' Fast Food'): 158 times
# ('Mithai', ' Street Food'): 148 times
# ('North Indian', ' Italian'): 139 times
# (' South Indian', ' Chinese'): 137 times
# ('Pizza', ' Fast Food'): 135 times
# (' Chinese', ' Continental'): 132 times
# ('Continental', ' North Indian'): 127 times
# ('Cafe', ' Italian'): 118 times
# ('Chinese', ' Thai'): 106 times
# ('North Indian', ' Street Food'): 103 times
# ('South Indian', ' Chinese'): 102 times
# ('Raw Meats', ' Fast Food'): 102 times
# ...

# %%
combination_ratings = defaultdict(list)
for index, row in df.iterrows():
    for combo in row['Cuisines']:
        combination_ratings[combo].append(row['Aggregate rating'])

average_ratings = {combo: sum(ratings) / len(ratings) for combo, ratings in combination_ratings.items()}

average_ratings_df = pd.DataFrame(average_ratings.items(), columns=['Cuisine Combination', 'Average Rating'])

sorted_average_ratings = average_ratings_df.sort_values(by='Average Rating', ascending=False)

print("Cuisine combinations with their average ratings:")
print(sorted_average_ratings)
# Out:
# Cuisine combinations with their average ratings:
#     Cuisine Combination  Average Rating
# 218               Sunda        4.900000
# 228            Scottish        4.700000
# 247              B�_rek        4.700000
# 108               Cajun        4.700000
# 77            Caribbean        4.666667
# ..                  ...             ...
# 178              Awadhi        0.760000
# 192             Afghani        0.414286
# 60              Mineira        0.000000
# 202      Cuisine Varies        0.000000
# 113             Persian        0.000000
#
# [249 rows x 2 columns]
